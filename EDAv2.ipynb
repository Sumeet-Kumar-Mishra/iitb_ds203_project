# %%
import pandas as pd  
import numpy as np
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (12, 8),
         'axes.labelsize': 19,
         'axes.titlesize':23,
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
def set_labels(title, xlabel="", ylabel=""):
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
dfIN = pd.read_csv("csv_files/INpreprocessed.csv")
dfGB = pd.read_csv("csv_files/GBpreprocessed.csv")
dfUS = pd.read_csv("csv_files/USpreprocessed.csv")
dfs = [dfIN,dfGB,dfUS]

# %%
dfIN.isnull().sum()
# Out:
# video_id                    0
# title                       0
# channel_title               0
# category_id                 0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               250
# trend_date                  0
# trend_month                 0
# trend_year                  0
# pub_date                    0
# pub_month                   0
# pub_year                    0
# pub_hour                    0
# file_path                   0
# dtype: int64

# %%
dfIN.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count  \
# count  30098.000000  3.009800e+04  3.009800e+04  3.009800e+04   30098.000000
# mean      21.408997  1.182208e+06  3.190725e+04  1.921989e+03    3159.406705
# std        6.749239  3.475862e+06  1.066138e+05  1.788343e+04   16457.743049
# min        1.000000  4.287000e+03  0.000000e+00  0.000000e+00       0.000000
# 25%       23.000000  1.369780e+05  1.131000e+03  1.300000e+02     112.000000
# 50%       24.000000  3.378320e+05  4.066000e+03  3.850000e+02     435.000000
# 75%       24.000000  8.799642e+05  1.856925e+04  1.163000e+03    1603.000000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06  827755.000000
#
#          trend_date   trend_month    trend_year      pub_date     pub_month  \
# count  30098.000000  30098.000000  30098.000000  30098.000000  30098.000000
# mean       5.283341     15.858462     17.766131     15.775168      5.344873
# std        3.795210      8.809644      0.423297      8.765619      3.831658
# min        1.000000      1.000000     17.000000      1.000000      1.000000
# 25%        2.000000      8.000000     18.000000      8.000000      2.000000
# 50%        4.000000     16.000000     18.000000     16.000000      4.000000
# 75%        6.000000     23.000000     18.000000     23.000000      6.000000
# max       12.000000     31.000000     18.000000     31.000000     12.000000
#
#            pub_year      pub_hour
# count  30098.000000  30098.000000
# mean      17.755432     10.616586
# std        0.429838      5.044901
# min       17.000000      0.000000
# 25%       18.000000      6.000000
# 50%       18.000000     11.000000
# 75%       18.000000     14.000000
# max       18.000000     23.000000

# %%
sns.set_style("white")
import matplotlib.image as mpimg
from PIL import Image
import requests
from io import BytesIO

countries = ["India","Britain","US"]

for j,(df,country) in enumerate(zip(dfs,countries)):
    view_df = df.sort_values(by='views',ascending=True,ignore_index=True)
    view_df = view_df.drop_duplicates(subset = 'video_id',keep='last',ignore_index=True)
    view_df = view_df.sort_values(by='views',ascending=False,ignore_index=True)

    fig,ax = plt.subplots(1,3,figsize=(12,4))
    #since local images are available for India
    if j==0:
        for i in range(3):
            img = mpimg.imread(view_df.file_path[i].replace("https://raw.githubusercontent.com/sheelfshah/iitb_ds203_project/master/",""))
            mpimg.imsave('results/{}most_trending.png'.format(i),img)
            ax[i].imshow(img)
            ax[i].set_xticks([])
            ax[i].set_yticks([])
            ax[i].set_xlabel(view_df.title[i][:20])
    
    else:
        for i in range(3):
            url = view_df.thumbnail_link[i]
            response = requests.get(url)
            img = Image.open(BytesIO(response.content))
            ax[i].imshow(img)
            ax[i].set_xticks([])
            ax[i].set_yticks([])
            ax[i].set_xlabel(view_df.title[i][:20])

    
    fig.suptitle("Most Viewed Videos "+country)
    plt.show()

# %%
sns.set_theme()

for i,(df,country) in enumerate(zip(dfs,countries)):
    

    if i==0:
        fig = plt.figure(constrained_layout = True)
        gs = fig.add_gridspec(2,2)
    else:
        fig = plt.figure(figsize=(12,4),constrained_layout = True)
        gs = fig.add_gridspec(1,2)
    fax1 = fig.add_subplot(gs[0,0])
    sns.histplot(df['views'], log_scale=True,ax = fax1,color = 'navy')
    fax1.set_title("Histogram of Views")
    fax1.set_xlabel("Views in log scale")
    fax1.set_ylabel("Numer of videos")
    #set_labels("Histogram of views", "Views", "Number of videos")

    fax2 = fig.add_subplot(gs[0,1])
    sns.histplot(df['likes'] + 1, log_scale=True,ax = fax2,color='teal')
    fax2.set_title("Histogram of Likes")
    fax2.set_xlabel("Likes in log scale")
    fax2.set_ylabel("Numer of videos")
    
    if i==0:
        fax3 = fig.add_subplot(gs[1,:])
        sns.histplot(df['pub_hour'],ax = fax3,color = 'coral')
        fax3.set_title("Histogram of Publish Hour")
        fax3.set_xlabel("Hour of Publishing")
        fax3.set_ylabel("Numer of videos")
    
    fig.suptitle(country)
    plt.savefig("results/"+str(country+" views and likes.png"))
    plt.show()

# %% [markdown]
# When converted to IST, these times indicate peaks at 12pm and 7 pm. <br>
#
# One takeaway here might be that the peak i of views for India is lesser than that of US and Britain as videos published in India have more local content that is viewed only in India whereas the ones published in US and Britain have more content that is globally viewed.<br>
#
# Further analysis is done for India.

# %%
#adding qqplots 

import statsmodels.api as sm

def normalize(sigma,mean,x):
    return (x-mean)/sigma

fig,ax = plt.subplots(1,2,figsize=(12,6))

sm.qqplot((dfIN['views'].dropna()).apply(lambda x: normalize(dfIN['views'].dropna().std(),dfIN['views'].dropna().mean(),x)),line = 's',ax=ax[0])
ax[0].set_title('QQplot for views')
sm.qqplot((dfIN['likes'].dropna()).apply(lambda x: normalize(dfIN['likes'].dropna().std(),dfIN['likes'].dropna().mean(),x)),line = 's',ax=ax[1])
ax[1].set_title('QQplot for likes')
plt.show()

# %% [markdown]
# Note that although the histograms look gaussian the qq plots indicate otherwise as for the histograms we have plotted the number of views in log scale. Hence the distribution seems to be exponential.

# %%
#finding the corelation between views, likes, dislikes, and comments
sns.set_style("white")
fig,ax = plt.subplots(1,3,figsize=(15,4))

for i,(df,country) in enumerate(zip(dfs,countries)):
   
    corr_df = df[['views','likes','comment_count','dislikes']]
    corr = corr_df.corr()
    im = ax[i].matshow(corr)
    ax[i].set_xticks(range(4))
    ax[i].set_xticklabels(['views','likes','comments','dislikes'],rotation=45)
    ax[i].set_yticks(range(4))
    ax[i].set_yticklabels(['views','likes','comments','dislikes'],rotation=45)
    ax[i].set_title("Correlation Matrix:- "+country)
    
fig.colorbar(im)    

#extent = ax[0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/correlation.png')

plt.show()

# %%
def col_func(word, font_size, position, orientation, font_path, random_state):
    colors = ["#fe0000", "#fdfe02", "#0bff01", "#011efe", "#fe00f6", "#f95d6a", "#ff7c43", "#ffa600"]
    return colors[len(word)%len(colors)]

fig,ax = plt.subplots(3,2,figsize=(14,24))
plt.axis("off") 
plt.tight_layout(pad = 0) 
for i,(df,country) in enumerate(zip(dfs,countries)):
    title  = df['title']
    desc = df['description']
    comment_words = '' 
    desc_words = ''
    stopwords = set(STOPWORDS) 

    for val in title: 

        val = str(val) 
        tokens = val.split() 

        comment_words += " ".join(tokens)+" "
    for val in desc:
        val = str(val) 
        tokens = val.split() 
        desc_words += " ".join(tokens)+" "

    wordcloud = WordCloud(width = 600, height = 600, 
                        stopwords = stopwords, 
                        min_font_size = 10, background_color="#000000",
                        color_func=col_func, max_words=100).generate(comment_words) 
    #mpimg.imsave('results/'+country+'title.png',wordcloud)
    wordcloud1 = WordCloud(width = 800, height = 800, 
                        stopwords = stopwords, 
                        min_font_size = 10, background_color="#000000",
                        color_func=col_func, max_words=100).generate(desc_words) 
    #mpimg.imsave('results/'+country+'desc.png',wordcloud1)

    #plt.figure(figsize = (8, 8), facecolor = None) 
    ax[i][0].imshow(wordcloud) 
    ax[i][0].set_title("Title Wordcloud "+country)
    ax[i][0].axis("off")
    ax[i][1].imshow(wordcloud1) 
    ax[i][1].set_title("Description Wordcloud "+country)
    ax[i][1].axis("off")
    
    

    #plt.title("Most occuring words in titles")
fig.savefig('results/wordcloud.png')
plt.show()

# %%
# videos that trended for the longest

for df,country in zip(dfs,countries):
    most_trending = df.groupby('video_id').size().sort_values(ascending=False).head(10)
    idx = most_trending.index.values
    tdf = df[df['video_id'].isin(idx)].drop_duplicates(subset=['video_id'])
    tdf['trending_days'] = tdf['video_id'].map(most_trending) 
    print('*'*100)
    print("Country : "+country)
    print('*'*100)
    display(tdf.drop(columns=['category_id','video_id']))
# Out:
# ****************************************************************************************************
# Country : India
# ****************************************************************************************************
#                                                    title  \
# 105    స‌మంత కంట‌త‌డి samantha becam emot samantha na...
# 14726  mill lo na guri ft sukh full song jaani satti ...
# 20346              garmi ke sideeffect ashish chanchlani
# 22102  sanju offici teaser ranbir kapoor rajkumar hirani
# 25778  tochan full video sidhu moosewala byg byrd son...
# 27794  sanju offici trailer ranbir kapoor rajkumar hi...
# 27795                 restaur sutiyapa ashish chanchlani
# 27805  golak bugni bank te batua full movi hd harish ...
# 28564                      result ka mahool amit bhadana
# 28787  कस्टमर केयर वाली छोरिया राजस्थानी सुपरहिट कॉमे...
#
#                  channel_title     views   likes  dislikes  comment_count  \
# 105              Friday Poster     31052      36        11              2
# 14726                 Geet MP3   2168315  117689      6907          10407
# 20346  ashish chanchlani vines   4227847  387791      9279          24003
# 22102             FoxStarHindi  18639195  511763     15606          32435
# 25778             Humble Music   5659320  112530      3180          10480
# 27794             FoxStarHindi  21739537  549875     16991          41068
# 27795  ashish chanchlani vines   4613979  337315     15396          27261
# 27805              Rhythm Boyz    225528    9336       222            438
# 28564             Amit Bhadana   3385971  326085      9541          38656
# 28787           RDC Rajasthani     75248    1572       170            101
#
#        comments_disabled  ratings_disabled  video_error_or_removed  \
# 105                False             False                   False
# 14726              False             False                   False
# 20346              False             False                   False
# 22102              False             False                   False
# 25778              False             False                   False
# 27794              False             False                   False
# 27795              False             False                   False
# 27805              False             False                   False
# 28564              False             False                   False
# 28787              False             False                   False
#
#                                              description  trend_date  \
# 105    స‌మంత కంట‌త‌డి samantha becam emot samantha na...          11
# 14726  geet mp3 gkdigit present new track mill lo na ...           2
# 20346  made special video summer season younkya aap b...           4
# 22102  live time dramat enigmat saga sanjay dutt come...           4
# 25778  humbl music present tochan singer sidhu moosew...           5
# 27794  live time dramat enigmat saga sanjay dutt come...           5
# 27795  present youth type peopl find indian restaur “...           5
# 27805  rhythm boyz entertain hayr omje studio present...           5
# 28564  video intens result days♠ download loco app ht...           6
# 28787  कस्टमर केयर वाली छोरिया राजस्थानी सुपरहिट कॉमे...           6
#
#        trend_month  trend_year  pub_date  pub_month  pub_year  pub_hour  \
# 105             14          17        13         11        17         8
# 14726           27          18        26          2        18        12
# 20346           14          18        13          4        18        14
# 22102           25          18        24          4        18         7
# 25778           18          18        17          5        18         7
# 27794           31          18        30          5        18         7
# 27795           31          18        30          5        18        13
# 27805           31          18        31          5        18        13
# 28564            5          18         4          6        18        15
# 28787            6          18         6          6        18         8
#
#                                                file_path  trending_days
# 105    https://raw.githubusercontent.com/sheelfshah/i...            417
# 14726  https://raw.githubusercontent.com/sheelfshah/i...             13
# 20346  https://raw.githubusercontent.com/sheelfshah/i...             13
# 22102  https://raw.githubusercontent.com/sheelfshah/i...             16
# 25778  https://raw.githubusercontent.com/sheelfshah/i...             13
# 27794  https://raw.githubusercontent.com/sheelfshah/i...             14
# 27795  https://raw.githubusercontent.com/sheelfshah/i...             13
# 27805  https://raw.githubusercontent.com/sheelfshah/i...             14
# 28564  https://raw.githubusercontent.com/sheelfshah/i...             12
# 28787  https://raw.githubusercontent.com/sheelfshah/i...             13
# ****************************************************************************************************
# Country : Britain
# ****************************************************************************************************
#                                                    title        channel_title  \
# 16186                                           daughter         Kylie Jenner
# 16187    jurass world fallen kingdom offici trailer 2 hd   Universal Pictures
# 16190  justin timberlak ’ full pepsi super bowl lii h...                  NFL
# 17015                        whethan dua lipa high audio      FiftyShadesVEVO
# 19380                 rich brian cold offici music video             88rising
# 19777          janel moná – make feel offici music video        Janelle Monáe
# 30612            miguel come chill ft j cole salaam remi           MiguelVEVO
# 31669  bhad bhabi feat lil yachti gucci flip flop off...          Bhad Bhabie
# 31996                              florenc machin hunger  FlorenceMachineVEVO
# 32810                         annemari 2002 offici video           Anne-Marie
#
#           views   likes  dislikes  comment_count  \
# 16186  20921796       0         0              0
# 16187   1999326   61833      1416           6400
# 16190   2027569   50251     15239          14413
# 17015    214026   21175       136            819
# 19380    654748   67049       706           6110
# 19777    631429   31117      1880           3234
# 30612    427939   36062       150           2204
# 31669   3094255  218766     16617          24018
# 31996    388954   41428       214           2557
# 32810   1070242  108344      1040           7571
#
#                                        thumbnail_link  comments_disabled  \
# 16186  https://i.ytimg.com/vi/BhIEIO0vaBE/default.jpg               True
# 16187  https://i.ytimg.com/vi/NooW_RbfdWI/default.jpg              False
# 16190  https://i.ytimg.com/vi/2z3EUY1aXdY/default.jpg              False
# 17015  https://i.ytimg.com/vi/ABLsSWE06q4/default.jpg              False
# 19380  https://i.ytimg.com/vi/Q17z9a03YaM/default.jpg              False
# 19777  https://i.ytimg.com/vi/tGRzz0oqgUE/default.jpg              False
# 30612  https://i.ytimg.com/vi/u_C4onVrr8U/default.jpg              False
# 31669  https://i.ytimg.com/vi/tsp7IOr7Q9A/default.jpg              False
# 31996  https://i.ytimg.com/vi/5GHXEGz3PJg/default.jpg              False
# 32810  https://i.ytimg.com/vi/Il-an3K9pjg/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 16186              True                   False
# 16187             False                   False
# 16190             False                   False
# 17015             False                   False
# 19380             False                   False
# 19777             False                   False
# 30612             False                   False
# 31669             False                   False
# 31996             False                   False
# 32810             False                   False
#
#                                              description  trend_date  \
# 16186  direct tyler ross wttylernmus jacob wilkinsons...           2
# 16187  jurass world fallen kingdom nin theater june 2...           2
# 16190  justin timberlak break pepsi super bowl lii ha...           2
# 17015  high offici audionsong avail fifti shade freed...           2
# 19380  coldnnamen avail worldwid httpsempirelnktoamen...           2
# 19777  “ make feel ” “ django jane ” avail httpsjanel...           2
# 30612  “ come chill ” ft j cole httpsmarturlitcomethr...           4
# 31669  bhad bhabi gucci flip flop ft lil yachti ⛵️ of...           5
# 31996  hungerdirect ag rojasproduc park pictureshigh ...           5
# 32810  get 2002 annemari ▶ httpadgt2002get speak mind...           5
#
#        trend_month  trend_year  pub_date  pub_month  pub_year  pub_hour  \
# 16186            5          18         4          2        18        20
# 16187            5          18         4          2        18        23
# 16190            5          18         5          2        18         1
# 17015            9          18         8          2        18        21
# 19380           21          18        20          2        18        13
# 19777           23          18        22          2        18        17
# 30612           26          18        25          4        18        16
# 31669            2          18         1          5        18        16
# 31996            4          18         3          5        18        18
# 32810            9          18         8          5        18        11
#
#        trending_days
# 16186             38
# 16187             38
# 16190             38
# 17015             37
# 19380             37
# 19777             37
# 30612             38
# 31669             37
# 31996             37
# 32810             38
# ****************************************************************************************************
# Country : US
# ****************************************************************************************************
#                                                    title      channel_title  \
# 33750               sam smith pray offici video ft logic  SamSmithWorldVEVO
# 33951                                 cobra kai season 2          Cobra Kai
# 34157                       charli puth boy offici audio       Charlie Puth
# 34550                    made mom cryher dream came true   Lucas and Marcus
# 34750                                  im scare cri much      grav3yardgirl
# 34751      youngboy never broke goe sneaker shop complex            Complex
# 34753       周杰倫 jay chou【不愛我就拉倒 dont love fine】offici mv    杰威爾音樂 JVR Music
# 34759                          ultim 30000 game pc setup      Unbox Therapy
# 34760           rooster teeth anim adventur milli seriou      Rooster Teeth
# 34949  bohemian rhapsodi teaser trailer hd 20th centu...   20th Century Fox
#
#          views   likes  dislikes  comment_count  \
# 33750   641944   72641      1133           4357
# 33951   378105   19998       395           4483
# 34157   981789   55917       616           3021
# 34550  2131702   54280      4696          10705
# 34750  1469627  188652      3124          33032
# 34751  1199587   49709      2380           7261
# 34753   916128   40485      1042           4746
# 34759  4700460  103430      8028          13293
# 34760   404162   17920        79            642
# 34949  4215671  161058      2198          10289
#
#                                        thumbnail_link  comments_disabled  \
# 33750  https://i.ytimg.com/vi/8h--kFui1JA/default.jpg              False
# 33951  https://i.ytimg.com/vi/WIV3xNz8NoM/default.jpg              False
# 34157  https://i.ytimg.com/vi/iILJvqrAQ_w/default.jpg              False
# 34550  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
# 34750  https://i.ytimg.com/vi/QBL8IRJ5yHU/default.jpg              False
# 34751  https://i.ytimg.com/vi/t4pRQ0jn23Q/default.jpg              False
# 34753  https://i.ytimg.com/vi/MAjY8mCTXWk/default.jpg              False
# 34759  https://i.ytimg.com/vi/r-3iathMo7o/default.jpg              False
# 34760  https://i.ytimg.com/vi/NBSAQenU2Bk/default.jpg              False
# 34949  https://i.ytimg.com/vi/6S9c5nnDd_s/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 33750             False                   False
# 33951             False                   False
# 34157             False                   False
# 34550             False                   False
# 34750             False                   False
# 34751             False                   False
# 34753             False                   False
# 34759             False                   False
# 34760             False                   False
# 34949             False                   False
#
#                                              description  trend_date  \
# 33750  stream download listen pray feat logic httpsam...           5
# 33951  first round ’ readi second cobra kai season 2 ...           5
# 34157  voicenot avail httpsatlanticlnktovoicenoteside...           5
# 34550  best mom ever tix sale httpswwwdobretourcomw p...           5
# 34750  never abl say thank enough thank family➡ click...           5
# 34751  youngboy never broke goe sneaker shop complex ...           5
# 34753  詞：周杰倫、宋健彰（彈頭） 曲：周杰倫憂鬱型男的走心旋律 用英式搖滾宣洩情傷不愛我就拉倒 寒...           5
# 34759  fortnit pubg far cri 5 game would play game pc...           5
# 34760  milli invit help sugar pine 7 event take serio...           5
# 34949  visit httpwwwputmeinbohemiancom chanc voic inc...           5
#
#        trend_month  trend_year  pub_date  pub_month  pub_year  pub_hour  \
# 33750           10          18         9          5        18        17
# 33951           11          18        10          5        18        17
# 34157           12          18        11          5        18         4
# 34550           14          18        13          5        18        18
# 34750           15          18        14          5        18        19
# 34751           15          18        14          5        18        14
# 34753           15          18        14          5        18        15
# 34759           15          18        13          5        18        19
# 34760           15          18        14          5        18        13
# 34949           16          18        15          5        18        13
#
#        trending_days
# 33750             29
# 33951             28
# 34157             29
# 34550             30
# 34750             29
# 34751             29
# 34753             29
# 34759             29
# 34760             29
# 34949             28

# %%
#to remove the distplot deprecated warning
import warnings
warnings.filterwarnings('ignore')

sns.set_theme()
fig,ax = plt.subplots(2,2,figsize=(14,8),constrained_layout=True)
for i,(df,country) in enumerate(zip(dfs,countries)):
    freq_df = df[['video_id','title','channel_title']]
    freq_df['counter'] = 1
    freq_df = freq_df.groupby('video_id',as_index=False).sum().sort_values(by = 'counter',ascending=False)

    #the most frequent one comes out to be the entries for which id is not available hence, removing that entry
    # id is #NAME?
    freq_df = freq_df.drop(axis=1,index=[0])
    #print(freq_df)
    
    sns.histplot(freq_df['counter'],ax=ax[i//2][i%2])
    #ax[i//2][i%2].set_box_aspect(10/len(ax[i//2][i%2].patches))
    ax[i//2][i%2].set_xlabel("Number of days")
    ax[i//2][i%2].set_ylabel("Number of videos")
    ax[i//2][i%2].set_xticks(range(0,max(freq_df['counter'])+1,2))
    ax[i//2][i%2].set_title(country)
    
plt.delaxes(ax=ax[1,1])
extent = ax[0,0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/days_trending.png')
plt.show()

# %%
# channels with most trending videos

fig,ax = plt.subplots(2,2,figsize=(16,12),constrained_layout=True)

for i,(df,country) in enumerate(zip(dfs,countries)):
    tdf = df.groupby("channel_title").size().reset_index(name="video_count") \
        .sort_values("video_count", ascending=False).head(19)
    sns.barplot(x="video_count", y="channel_title", data=tdf,
                palette=sns.color_palette('gist_heat', n_colors=25)[3:],ax=ax[i//2][i%2]);
    ax[i//2][i%2].set_title("Most Trending YouTubers : "+country)
    ax[i//2][i%2].set_xlabel("Number of trending videos")
    ax[i//2][i%2].set_ylabel("Channel Name")
    
    
extent = ax[0,0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/trending_channels.png')
plt.delaxes(ax=ax[1,1])
plt.show()

# %%
import json

with open('json_files/categories.json') as f:
    categoriesIN = json.load(f)
with open('json_files/GB_category_id.json') as f:
    categoriesGB = json.load(f)
with open('json_files/US_category_id.json') as f:
    categoriesUS = json.load(f)

# %%
cat_mapIN={}
cat_mapGB={}
cat_mapUS={}
for cat in categoriesIN["items"]:
    cat_mapIN[cat["id"]]=cat["snippet"]["title"]
for cat in categoriesGB["items"]:
    cat_mapGB[cat["id"]]=cat["snippet"]["title"]
for cat in categoriesUS["items"]:
    cat_mapUS[cat["id"]]=cat["snippet"]["title"]

# %%
def get_catIN(n):
    try:
        return cat_mapIN[str(n)]
    except:
        return "Other"
    
def get_catGB(n):
    try:
        return cat_mapGB[str(n)]
    except:
        return "Other"
    
def get_catUS(n):
    try:
        return cat_mapUS[str(n)]
    except:
        return "Other"

# %%
dfIN["category_id"]=dfIN["category_id"].apply(get_catIN)
dfGB["category_id"]=dfGB["category_id"].apply(get_catGB)
dfUS["category_id"]=dfUS["category_id"].apply(get_catUS)

# %%
display(dfIN.loc[dfIN['category_id']!='Other'])
# Out:
#           video_id                                              title  \
# 0      kzwfHumJyYc  sharri mann cute munda song teaser parmish ver...
# 1      zUZ1z7FwLc8  पीरियड्स के समय पेट पर पति करता ऐसा देखकर दंग ...
# 2      10L1hZ9qa58    stylish star allu arjun chaysam wed recept tfpc
# 3      N1vE8iiEg64                       eruma saani tamil vs english
# 4      kJzGH0PVQHQ  samantha becam emot samantha naga chaithanya m...
# ...            ...                                                ...
# 30093  iNHecA3PJCo  फेकू आशिक़ राजस्थान की सबसे शानदार कॉमेडी रमकु...
# 30094  dpPmPbhcslM                               seetha flower ep 364
# 30095  mV6aztP58f8  bhramanam episod 87 12 june 2018 mazhavil mano...
# 30096  qxqDNP1bDEw  nua bohu full ep 285 13th june 2018 odia seria...
# 30097  wERgpPK44w0  ee nagaraniki emaindi trailer tharun bhascker ...
#
#             channel_title       category_id    views  likes  dislikes  \
# 0         Lokdhun Punjabi  Film & Animation  1096327  33966       798
# 1                 HJ NEWS   News & Politics   590101    735       904
# 2                    TFPC     Entertainment   473988   2011       243
# 3             Eruma Saani            Comedy  1242680  70353      1624
# 4              Filmylooks     Entertainment   464015    492       293
# ...                   ...               ...      ...    ...       ...
# 30093      RDC Rajasthani            Comedy   214378   3291       404
# 30094          Flowers TV     Entertainment   406828   1726       478
# 30095   Mazhavil Manorama     Entertainment   386319   1216       453
# 30096           Tarang TV     Entertainment   130263    698       115
# 30097  Suresh Productions     Entertainment  1278249  22466      1609
#
#        comment_count  comments_disabled  ratings_disabled  \
# 0                882              False             False
# 1                  0               True             False
# 2                149              False             False
# 3               2684              False             False
# 4                 66              False             False
# ...              ...                ...               ...
# 30093            196              False             False
# 30094           1428              False             False
# 30095            697              False             False
# 30096             65              False             False
# 30097           1205              False             False
#
#        video_error_or_removed  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 30093                   False
# 30094                   False
# 30095                   False
# 30096                   False
# 30097                   False
#
#                                              description  trend_date  \
# 0      present sharri mann latest punjabi song cute m...          11
# 1      पीरियड्स के समय पेट पर पति करता ऐसा देखकर दंग ...          11
# 2      watch stylish star allu arjun chaysam wed rece...          11
# 3      video showcas differ peopl speak english tamil...          11
# 4      samantha becam emot samantha naga chaithanya m...          11
# ...                                                  ...         ...
# 30093  prg music rdc rajasthani present फेकू आशिक़ ra...           6
# 30094  flower r rahman showbook ticket httpsgoogluyaq...           6
# 30095  subscrib mazhavil manorama daili entertain dos...           6
# 30096  nuabohu stori rustic villag girl want becom id...           6
# 30097  check ee nagaraniki emaindi trailer eenagarani...           6
#
#        trend_month  trend_year  pub_date  pub_month  pub_year  pub_hour  \
# 0               14          17        12         11        17        12
# 1               14          17        13         11        17         5
# 2               14          17        12         11        17        15
# 3               14          17        12         11        17         7
# 4               14          17        13         11        17         1
# ...            ...         ...       ...        ...       ...       ...
# 30093           14          18        13          6        18         8
# 30094           14          18        13          6        18        11
# 30095           14          18        13          6        18         5
# 30096           14          18        13          6        18        15
# 30097           14          18        10          6        18         4
#
#                                                file_path
# 0      https://raw.githubusercontent.com/sheelfshah/i...
# 1      https://raw.githubusercontent.com/sheelfshah/i...
# 2      https://raw.githubusercontent.com/sheelfshah/i...
# 3      https://raw.githubusercontent.com/sheelfshah/i...
# 4      https://raw.githubusercontent.com/sheelfshah/i...
# ...                                                  ...
# 30093  https://raw.githubusercontent.com/sheelfshah/i...
# 30094  https://raw.githubusercontent.com/sheelfshah/i...
# 30095  https://raw.githubusercontent.com/sheelfshah/i...
# 30096  https://raw.githubusercontent.com/sheelfshah/i...
# 30097  https://raw.githubusercontent.com/sheelfshah/i...
#
# [29996 rows x 20 columns]

# %%
# categories with most trending videos
fig,ax = plt.subplots(2,2,figsize=(16,12),constrained_layout=True)

for i,(df,country) in enumerate(zip(dfs,countries)):
    tdf = df.groupby("category_id").size().reset_index(name="video_count") \
        .sort_values("video_count", ascending=False).head(10)
    sns.barplot(x="video_count", y="category_id", data=tdf,
                palette=sns.color_palette('gist_heat', n_colors=25)[3:],ax=ax[i//2][i%2]);
    ax[i//2][i%2].set_title("Most Trending categories : "+country)
    ax[i//2][i%2].set_xlabel("Number of trending videos")
    ax[i//2][i%2].set_ylabel("Category")
    
    
#extent = ax[0,0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/trending_category.png')
plt.delaxes(ax=ax[1,1])
plt.show()

# %%
fig,ax = plt.subplots(3,2,figsize=(12,12),constrained_layout=True)

for i,(df,country) in enumerate(zip(dfs,countries)):
    tdf = df.sort_values('views',ignore_index=True)

    #only keeping the video with the max views
    tdf.drop_duplicates(subset = 'video_id',keep='last',inplace=True,ignore_index=True)
    tdf = tdf[['title','views','description']]
    tdf['description'] = tdf['description'].astype(str)
    tdf['title'] = tdf['title'].astype(str)
    tdf['title_length'] = 0
    tdf['descrip_length'] = 0
    for j,x in enumerate(tdf['title']):
        tdf.at[j,'title_length'] = len(tdf.at[j,'title'])
        tdf.at[j,'descrip_length'] = len(tdf.at[j,'description'])

    

    sns.histplot(tdf['title_length'],ax=ax[i][0],color='midnightblue')
    ax[i][0].set_xlabel('Title Length')
    ax[i][0].set_ylabel('Number of videos')
    ax[i][0].set_title('Histogram of title length: ' + country)
    sns.histplot(tdf['descrip_length'],ax=ax[i][1],color='crimson')
    ax[i][1].set_xlabel('Description Length')
    ax[i][1].set_ylabel('Number of videos')
    ax[i][1].set_title('Histogram of Description length: ' + country)
    
#extent = ax[0,0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/title_len.png')

plt.show()

# %%
import statsmodels.api as sm


def normalize(sigma,mean,x):
    return (x-mean)/sigma

fig,ax = plt.subplots(3,2,figsize=(12,12),constrained_layout=True)

for i,(df,country) in enumerate(zip(dfs,countries)):
    tdf = df.sort_values('views',ignore_index=True)

    #only keeping the video with the max views
    tdf.drop_duplicates(subset = 'video_id',keep='last',inplace=True,ignore_index=True)
    tdf = tdf[['title','views','description']]
    tdf['description'] = tdf['description'].astype(str)
    tdf['title'] = tdf['title'].astype(str)
    tdf['title_length'] = 0
    tdf['descrip_length'] = 0
    for j,x in enumerate(tdf['title']):
        tdf.at[j,'title_length'] = len(tdf.at[j,'title'])
        tdf.at[j,'descrip_length'] = len(tdf.at[j,'description'])

    

    sm.qqplot((tdf['title_length']).apply(lambda x: normalize(tdf['views'].std(),tdf['views'].mean(),x)),line = 's',ax=ax[i][0])
    #ax[i][0].set_xlabel('Title Length')
    #ax[i][0].set_ylabel('Number of videos')
    ax[i][0].set_title('qqplot of title length: ' + country)
    sm.qqplot((tdf['descrip_length']).apply(lambda x: normalize(tdf['views'].std(),tdf['views'].mean(),x)),line = 's',ax=ax[i][1])
    #ax[i][1].set_xlabel('Description Length')
    #ax[i][1].set_ylabel('Number of videos')
    ax[i][1].set_title('qqplot of Description length: ' + country)
    
#extent = ax[0,0].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig('results/title_len_qqplot.png')

plt.show()

# %%
for df in dfs:
    df.drop(df[df['dislikes']==0].index, inplace=True)
    df["l_dl_ratio"]=df["likes"]/df["dislikes"]

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.catplot(x="category_id", y="l_dl_ratio", kind = 'bar', data=dfIN, palette = "rainbow", height=8)
plt.xticks(rotation="70")
set_labels("Likes to dislikes ratio for various categories", "Category", "Ratio")
plt.savefig('results/likes_dis.png')
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.catplot(x="category_id", y="views", kind = 'bar', data=dfIN, palette = "rainbow", height=8)
plt.xticks(rotation="70")
set_labels("Most viewed categories", "Category", "Views")
plt.savefig('results/most_viewed_cat.png')
plt.show()

# %% [markdown]
# We observe that not too many gaming videos are trending but they attract a lot of views.
