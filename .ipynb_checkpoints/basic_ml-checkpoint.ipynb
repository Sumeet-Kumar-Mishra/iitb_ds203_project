# %%
from PIL import Image
import requests
from io import BytesIO
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("INpreprocessed.csv")

# %%
response = requests.get(df.file_path[0])
img = Image.open(BytesIO(response.content))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=120x90 at 0x7EFEDF51EC40>

# %%
np.asarray(img)[0,0]
# Out:
# array([11,  2,  0], dtype=uint8)

# %%
np.asarray(img).shape
# Out:
# (90, 120, 3)

# %%
def get_rgb(filename):
    img = np.asarray(Image.open(open(filename, 'rb')))
    return img.reshape(-1, 3)

# %%
im = get_rgb(df.file_path[0].replace(
        "https://raw.githubusercontent.com/sheelfshah/iitb_ds203_project/master/", ""))
im[0]
# Out:
# array([11,  2,  0], dtype=uint8)

# %%
import sklearn
from sklearn.cluster import MiniBatchKMeans

# %%
km = MiniBatchKMeans(n_clusters=10, batch_size=90*120)

# %%
for i, path in enumerate(df.file_path.sample(frac=1)):
    im = get_rgb(path.replace(
        "https://raw.githubusercontent.com/sheelfshah/iitb_ds203_project/master/", ""))
    km = km.partial_fit(im)

# %%
lab = km.labels_
y = np.bincount(lab)
ii = np.nonzero(y)[0]
np.vstack((ii,y[ii])).T
# Out:
# array([[   0,  868],
#        [   1, 1762],
#        [   2, 1056],
#        [   3, 3592],
#        [   4, 1345],
#        [   5,  584],
#        [   6, 1579],
#        [   7,    4],
#        [   8,    8],
#        [   9,    2]])

# %%
cc = km.cluster_centers_
cc[ii]
# Out:
# array([[238.14374282, 238.20018837, 236.81014099],
#        [ 42.39049247,  32.30180316,  37.09846998],
#        [160.10365253, 153.08985955, 156.14669569],
#        [  3.79214254,   2.34199871,   3.08573374],
#        [134.3022327 , 110.24018498,  95.99750617],
#        [214.57193595, 195.70976715, 179.24065802],
#        [ 82.71483417,  70.61405476,  64.63178572],
#        [ 49.15130004, 111.83999259, 169.41690474],
#        [216.03139981, 162.23976228,  81.41979292],
#        [168.62143797,  43.67815722,  37.02068398]])

# %%
cc[ii].shape
# Out:
# (10, 3)

# %%
cc = np.c_[cc[ii], np.ones(cc[ii].shape[0])*255]

# %%
cc
# Out:
# array([[238.14374282, 238.20018837, 236.81014099, 255.        ],
#        [ 42.39049247,  32.30180316,  37.09846998, 255.        ],
#        [160.10365253, 153.08985955, 156.14669569, 255.        ],
#        [  3.79214254,   2.34199871,   3.08573374, 255.        ],
#        [134.3022327 , 110.24018498,  95.99750617, 255.        ],
#        [214.57193595, 195.70976715, 179.24065802, 255.        ],
#        [ 82.71483417,  70.61405476,  64.63178572, 255.        ],
#        [ 49.15130004, 111.83999259, 169.41690474, 255.        ],
#        [216.03139981, 162.23976228,  81.41979292, 255.        ],
#        [168.62143797,  43.67815722,  37.02068398, 255.        ]])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
fig = plt.figure(figsize = (15, 12))
ax = plt.axes(projection ="3d")
ax.scatter3D(cc[:, 0], cc[:, 1], cc[:, 2], color=cc/255, s=10*np.sqrt(y[ii]), depthshade=False)
ax.w_xaxis.set_pane_color((1, 0, 0, 0.2))
ax.w_yaxis.set_pane_color((0, 1, 0, 0.2))
ax.w_zaxis.set_pane_color((0, 0, 1, 0.2))
ax.set_facecolor((0.8, 0.8, 0.8))

# %%
import seaborn as sns

# %%
color_centers=[]
for col in cc:
    color_centers.append(mpl.colors.to_hex(col/255))
sns.palplot(sns.color_palette(color_centers))
