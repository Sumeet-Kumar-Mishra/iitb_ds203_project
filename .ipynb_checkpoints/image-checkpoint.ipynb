# %%
from PIL import Image
import requests
from io import BytesIO
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("INpreprocessed.csv")

# %%
response = requests.get(df.file_path[0])
img = Image.open(BytesIO(response.content))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=120x90 at 0x7F4AC98ACE50>

# %%
np.asarray(img)[0, 0]
# Out:
# array([11,  2,  0], dtype=uint8)

# %%
np.asarray(img).shape
# Out:
# (90, 120, 3)

# %%
def get_rgb(filename):
    img = np.asarray(Image.open(open(filename, 'rb')))
    return img.reshape(-1, 3)

# %%
im = get_rgb(df.file_path[0].replace(
        "https://raw.githubusercontent.com/sheelfshah/iitb_ds203_project/master/", ""))
im[0]
# Out:
# array([11,  2,  0], dtype=uint8)

# %%
import sklearn
from sklearn.cluster import MiniBatchKMeans

# %%
km = MiniBatchKMeans(n_clusters=10, batch_size=90*120)

# %%
for i, path in enumerate(df.file_path.sample(frac=1)):
    im = get_rgb(path.replace(
        "https://raw.githubusercontent.com/sheelfshah/iitb_ds203_project/master/", ""))
    km = km.partial_fit(im)
    if (i+1)%5000==0:
        break

# %%
lab = km.labels_
y = np.bincount(lab)
ii = np.nonzero(y)[0]
np.vstack((ii,y[ii])).T
# Out:
# array([[   0, 4133],
#        [   1,  362],
#        [   2, 1561],
#        [   3, 2998],
#        [   5,  368],
#        [   6,  471],
#        [   7,  430],
#        [   8,  477]])

# %%
cc = km.cluster_centers_
cc[ii]
# Out:
# array([[  5.59896366,   3.40522847,   3.93430317],
#        [209.75939564, 188.26723989, 173.77975062],
#        [ 93.96041722,  94.37278381,  99.06797999],
#        [ 37.23267427,  42.07535   ,  57.4776812 ],
#        [237.14457463, 236.76184279, 234.86424939],
#        [173.93513975, 122.09194738,  97.07926778],
#        [129.08294402, 150.79556223, 167.45279565],
#        [ 88.44709639,  49.88952274,  34.05704588]])

# %%
cc[ii].shape
# Out:
# (8, 3)

# %%
cc = np.c_[cc[ii], np.ones(8)*255]

# %%
cc
# Out:
# array([[  5.59896366,   3.40522847,   3.93430317, 255.        ],
#        [209.75939564, 188.26723989, 173.77975062, 255.        ],
#        [ 93.96041722,  94.37278381,  99.06797999, 255.        ],
#        [ 37.23267427,  42.07535   ,  57.4776812 , 255.        ],
#        [237.14457463, 236.76184279, 234.86424939, 255.        ],
#        [173.93513975, 122.09194738,  97.07926778, 255.        ],
#        [129.08294402, 150.79556223, 167.45279565, 255.        ],
#        [ 88.44709639,  49.88952274,  34.05704588, 255.        ]])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
fig = plt.figure(figsize = (15, 12))
ax = plt.axes(projection ="3d")
ax.scatter3D(cc[:, 0], cc[:, 1], cc[:, 2], color=cc/255, s=10*np.sqrt(y[ii]), depthshade=False)
ax.w_xaxis.set_pane_color((1, 0, 0, 0.2))
ax.w_yaxis.set_pane_color((0, 1, 0, 0.2))
ax.w_zaxis.set_pane_color((0, 0, 1, 0.2))
ax.set_facecolor((0.8, 0.8, 0.8))
